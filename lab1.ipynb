# %% [markdown]
# <a href="https://colab.research.google.com/github/Stacey-velik/lab-02-/blob/main/lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Лабораторная работа: Google Colab
#
# **Выполнила:** Анастасия Андреевна
#
#
# ## Цель работы
# Изучить создание и запуск кода в Google Colab, работу с текстовыми ячейками Markdown, математическими формулами и совместным доступом к notebook.

# %% [markdown]
# ## Задание 2. Первая программа
# Выполним программу, которая выводит текст на экран.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# **Ожидаемый результат:** `Hello, World!`

# %% [markdown]
# ## Задание 3. Переменные и сложение
#
# Первая буква фамилии Velikotskaya — `V`, её номер в английском алфавите равен 22.
# Вторая буква — `E`, её номер равен 5.

# %%
Velikotskaya = 22
group_name = 5
Velikotskaya + group_name

# %% [markdown]
# **Ожидаемый результат:** `27`

# %% [markdown]
# ## Задание 4. Форматирование текста
#
# This is **bold**.
#
# This is *italic*.
#
# This is ~strikethrough~.
#
# ### Собственный пример
#
# Я изучаю **Google Colab**.
#
# Мне удобно писать *программы на Python* в браузере.
#
# Ошибки нельзя ~~оставлять без проверки~~ игнорировать перед сдачей работы.

# %% [markdown]
# ## Задание 5. Математические формулы
#
# Формула из задания:
#
# $\sqrt{3x-1}+(1+x)^2$
#
# Собственная формула:
#
# $\sqrt{2x+5} + (x-3)^2 - \frac{10}{x+1}$

# %% [markdown]
# ## Итог
# В работе созданы и выполнены кодовые ячейки Python, применены возможности Markdown и LaTeX для оформления текста и формул. Перед сдачей рекомендуется выбрать **Среда выполнения → Выполнить все**, убедиться в отсутствии ошибок и сохранить notebook.
